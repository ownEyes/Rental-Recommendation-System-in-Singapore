# %%
from surprise import KNNBasic
from surprise import KNNWithMeans
from surprise import SVD
from surprise import SVDpp
from surprise import NMF
from surprise import Dataset
from surprise import accuracy
from surprise import Reader
from surprise.model_selection import train_test_split
from surprise.model_selection import cross_validate
from surprise.model_selection import GridSearchCV
from surprise import dump

import os
import numpy as np
import pandas as pd

# %%
ratings_df = pd.read_csv('./csv_output/ratingInfo.csv')

ratings_df = ratings_df[['userID', 'listing_id', 'rating']]
# ratings_df = ratings_df.groupby(['userID', 'listing_id']).agg({'estimated_rating_flair': 'mean'}).reset_index()
ratings_df.columns = ['user_id','item_id','rating']
ratings_df = ratings_df.drop(ratings_df[ratings_df.rating == 0].index)

 # convert to surprise format
reader = Reader(rating_scale=(0,5)) # assumes datafile contains: user, item, ratings (in this order)
data = Dataset.load_from_df(ratings_df, reader)

# %%
svd_param_grid = {
    'n_factors': [50, 100, 150],
    'n_epochs': [20, 30, 50],
    'lr_all': [0.002, 0.005, 0.007],
    'reg_all': [0.02, 0.04, 0.06],
    'lr_bu': [0.005, 0.01],
    'lr_bi': [0.005, 0.01],
    'reg_bu': [0.01, 0.02],
    'reg_bi': [0.01, 0.02],
    'lr_pu': [0.005, 0.01],
    'lr_qi': [0.005, 0.01],
    'reg_pu': [0.01, 0.02],
    'reg_qi': [0.01, 0.02]
}

nmf_param_grid = {
    'n_factors': [10, 20, 30, 40, 50,100],
    'n_epochs': [50, 100, 150],
    'lr_bu': [0.005, 0.01],
    'lr_bi': [0.005, 0.01],
    'reg_pu': [0.01, 0.02],
    'reg_qi': [0.01, 0.02],
    'reg_bu': [0.01, 0.02],
    'reg_bi': [0.01, 0.02]
}

models = {'SVD': SVD, 'NMF': NMF}

best_model = None
best_params = None
best_mae = float('inf')
best_model_name = ""

for model_name, model_class in models.items():
    if model_name == 'SVD':
        param_grid = svd_param_grid
    elif model_name == 'NMF':
        param_grid = nmf_param_grid
    
    gs = GridSearchCV(model_class, param_grid, measures=['rmse', 'mae'], cv=3)
    gs.fit(data)
    
    print(f"\nResults for {model_name}:")
    print("Best parameters: ", gs.best_params['mae'])
    print("Best MAE: ", gs.best_score['mae'])

    if gs.best_score['mae'] < best_mae:
        best_mae = gs.best_score['mae']
        best_model = gs.best_estimator['mae']
        best_params = gs.best_params['mae']
        best_model_name = model_name

print(f"\nOverall best model: {best_model_name} with parameters {best_params} and MAE = {best_mae}")
# Out:
# Results for SVD:
# Best parameters:  {'n_factors': 100, 'n_epochs': 50, 'lr_all': 0.007, 'reg_all': 0.02, 'lr_bu': 0.005, 'lr_bi': 0.005, 'reg_bu': 0.02, 'reg_bi': 0.01, 'lr_pu': 0.01, 'lr_qi': 0.01, 'reg_pu': 0.01, 'reg_qi': 0.02}
# Best MAE:  0.6341113734545956
#
# Results for NMF:
# Best parameters:  {'n_factors': 100, 'n_epochs': 50, 'lr_bu': 0.005, 'lr_bi': 0.005, 'reg_pu': 0.01, 'reg_qi': 0.01, 'reg_bu': 0.01, 'reg_bi': 0.01}
# Best MAE:  0.6542914596567718
#
# Overall best model: SVD with parameters {'n_factors': 100, 'n_epochs': 50, 'lr_all': 0.007, 'reg_all': 0.02, 'lr_bu': 0.005, 'lr_bi': 0.005, 'reg_bu': 0.02, 'reg_bi': 0.01, 'lr_pu': 0.01, 'lr_qi': 0.01, 'reg_pu': 0.01, 'reg_qi': 0.02} and MAE = 0.6341113734545956

# %%
trainset = data.build_full_trainset()
test_model=best_model
test_model.fit(trainset)

# %%
from surprise import dump
model_filename = './fileOutput/best_matrix_factorization_model.surprise'
file_name = os.path.expanduser(model_filename)
dump.dump(file_name, algo=test_model)
# joblib.dump(best_model, model_file_name)
print(f"Model saved to {file_name}")
# Out:
# Model saved to ./fileOutput/best_matrix_factorization_model.surprise

# %%
# import joblib
from surprise import dump
model_filename = './fileOutput/best_matrix_factorization_model.surprise'
file_name = os.path.expanduser(model_filename)
dump.dump(file_name, algo=best_model)
# joblib.dump(best_model, model_file_name)
print(f"Model saved to {file_name}")
# Out:
# Model saved to ./fileOutput/best_matrix_factorization_model.surprise

# %%
from collections import defaultdict

def get_top_n(predictions, n=10):
    # First map the predictions to each user.
    top_n = defaultdict(list)
    for uid, iid, true_r, est, _ in predictions:
        top_n[uid].append((iid, est))
    # Then sort the predictions for each user and retrieve the k highest ones.
    for uid, user_ratings in top_n.items():
        user_ratings.sort(key=lambda x: x[1], reverse=True) # sort on predicted rating
        top_n[uid] = user_ratings[:n]
    return top_n
\

# def recommend(df, model,user_id):
#     recommend_default_topn=10
#     if 'user_id' not in df.columns or 'item_id' not in df.columns:
#         raise ValueError("DataFrame must contain 'user_id' and 'item_id' columns")
    
#     # trainset = data.build_full_trainset()
#     # model.trainset=trainset
#     user_data = df[df['user_id'] == user_id]
#     testset = list(user_data.itertuples(index=False, name=None))

#     predictions = model.test(testset)
#     top_n = get_top_n(predictions, n=recommend_default_topn)
#     return top_n

def recommend(df, model, user_id, top_n=10):
    if 'user_id' not in df.columns or 'item_id' not in df.columns:
        raise ValueError("DataFrame must contain 'user_id' and 'item_id' columns")
    
    # 获取所有唯一的物品ID
    item_ids = df['item_id'].unique()
    
    # 存储预测的评分
    predictions = defaultdict(float)
    
    # 对于每个物品ID，预测用户的评分
    for item_id in item_ids:
        # uid = str(user_id)
        # iid = str(item_id)
        # model.predict() 返回的是一个Prediction对象，需要通过.est获取预测评分
        predictions[item_id] = model.predict(user_id, item_id, verbose=True).est
    
    # 根据评分对物品进行排序，取前top_n个
    recommended_items = sorted(predictions.items(), key=lambda x: x[1], reverse=True)[:top_n]
    
    # 返回推荐物品的ID和预测评分
    return recommended_items

# %%
# model = joblib.load(model_file_name)
model_filename = './fileOutput/best_matrix_factorization_model.surprise'
file_name = os.path.expanduser(model_filename)
trainset, model = dump.load(file_name)
# model.trainset=trainset
rating_info = pd.read_csv('./csv_output/ratingInfo.csv')
item_info=pd.read_csv('./dataSource/final_data.csv')



# 创建一个新的DataFrame，为特定用户生成推荐

rating_info = rating_info[['userID', 'listing_id', 'rating']]
# ratings_df = ratings_df.groupby(['userID', 'listing_id']).agg({'estimated_rating_flair': 'mean'}).reset_index()
rating_info.columns = ['user_id','item_id','rating']
rating_info = rating_info.drop(rating_info[rating_info.rating == 0].index)

# reader = Reader(rating_scale=(0,5)) # assumes datafile contains: user, item, ratings (in this order)
# data = Dataset.load_from_df(rating_info, reader)
# trainset = data.build_full_trainset()

recommendations = recommend(rating_info,model,5)
recommendations
# Out:
# user: 5          item: 71609      r_ui = None   est = 4.67   {'was_impossible': False}
# user: 5          item: 3209752    r_ui = None   est = 4.48   {'was_impossible': False}
# user: 5          item: 3304326    r_ui = None   est = 4.59   {'was_impossible': False}
# user: 5          item: 3667894    r_ui = None   est = 4.48   {'was_impossible': False}
# user: 5          item: 3717196    r_ui = None   est = 4.28   {'was_impossible': False}
# user: 5          item: 71896      r_ui = None   est = 3.93   {'was_impossible': False}
# user: 5          item: 3802621    r_ui = None   est = 4.29   {'was_impossible': False}
# user: 5          item: 3803160    r_ui = None   est = 4.26   {'was_impossible': False}
# user: 5          item: 3980202    r_ui = None   est = 4.78   {'was_impossible': False}
# user: 5          item: 3981252    r_ui = None   est = 4.29   {'was_impossible': False}
# user: 5          item: 71903      r_ui = None   est = 4.33   {'was_impossible': False}
# user: 5          item: 3990431    r_ui = None   est = 4.53   {'was_impossible': False}
# user: 5          item: 4008423    r_ui = None   est = 4.83   {'was_impossible': False}
# user: 5          item: 275343     r_ui = None   est = 4.38   {'was_impossible': False}
# user: 5          item: 275344     r_ui = None   est = 4.62   {'was_impossible': False}
# user: 5          item: 289234     r_ui = None   est = 4.88   {'was_impossible': False}
# user: 5          item: 294281     r_ui = None   est = 4.30   {'was_impossible': False}
# user: 5          item: 4054698    r_ui = None   est = 4.16   {'was_impossible': False}
# user: 5          item: 4069756    r_ui = None   est = 4.62   {'was_impossible': False}
# user: 5          item: 4271250    r_ui = None   est = 4.63   {'was_impossible': False}
# user: 5          item: 4441346    r_ui = None   est = 4.54   {'was_impossible': False}
# user: 5          item: 4486217    r_ui = None   est = 4.73   {'was_impossible': False}
# user: 5          item: 4499317    r_ui = None   est = 4.65   {'was_impossible': False}
# user: 5          item: 324945     r_ui = None   est = 3.71   {'was_impossible': False}
# user: 5          item: 330095     r_ui = None   est = 3.77   {'was_impossible': False}
# user: 5          item: 369141     r_ui = None   est = 4.33   {'was_impossible': False}
# user: 5          item: 369145     r_ui = None   est = 4.03   {'was_impossible': False}
# user: 5          item: 4526703    r_ui = None   est = 4.77   {'was_impossible': False}
# user: 5          item: 4541072    r_ui = None   est = 4.32   {'was_impossible': False}
# user: 5          item: 4541183    r_ui = None   est = 4.98   {'was_impossible': False}
# user: 5          item: 4561032    r_ui = None   est = 4.18   {'was_impossible': False}
# user: 5          item: 4664392    r_ui = None   est = 4.18   {'was_impossible': False}
# user: 5          item: 395191     r_ui = None   est = 4.82   {'was_impossible': False}
# user: 5          item: 468782     r_ui = None   est = 4.85   {'was_impossible': False}
# user: 5          item: 4712676    r_ui = None   est = 4.53   {'was_impossible': False}
# user: 5          item: 4741630    r_ui = None   est = 4.56   {'was_impossible': False}
# user: 5          item: 4771752    r_ui = None   est = 4.76   {'was_impossible': False}
# user: 5          item: 4863317    r_ui = None   est = 4.45   {'was_impossible': False}
# user: 5          item: 4869221    r_ui = None   est = 4.46   {'was_impossible': False}
# user: 5          item: 4926170    r_ui = None   est = 3.91   {'was_impossible': False}
# user: 5          item: 4973227    r_ui = None   est = 4.52   {'was_impossible': False}
# user: 5          item: 606784     r_ui = None   est = 4.36   {'was_impossible': False}
# user: 5          item: 654191     r_ui = None   est = 4.21   {'was_impossible': False}
# user: 5          item: 696136     r_ui = None   est = 4.49   {'was_impossible': False}
# user: 5          item: 4989903    r_ui = None   est = 4.56   {'was_impossible': False}
# user: 5          item: 5040689    r_ui = None   est = 4.65   {'was_impossible': False}
# user: 5          item: 5052014    r_ui = None   est = 4.32   {'was_impossible': False}
# user: 5          item: 5116961    r_ui = None   est = 4.55   {'was_impossible': False}
# user: 5          item: 747813     r_ui = None   est = 4.36   {'was_impossible': False}
# user: 5          item: 5233415    r_ui = None   est = 4.68   {'was_impossible': False}
# user: 5          item: 5253599    r_ui = None   est = 4.71   {'was_impossible': False}
# user: 5          item: 5339318    r_ui = None   est = 4.35   {'was_impossible': False}
# user: 5          item: 5446857    r_ui = None   est = 4.47   {'was_impossible': False}
# user: 5          item: 5448209    r_ui = None   est = 4.61   {'was_impossible': False}
# user: 5          item: 5464246    r_ui = None   est = 4.81   {'was_impossible': False}
# user: 5          item: 5504230    r_ui = None   est = 4.47   {'was_impossible': False}
# user: 5          item: 5551665    r_ui = None   est = 4.50   {'was_impossible': False}
# user: 5          item: 747816     r_ui = None   est = 4.41   {'was_impossible': False}
# user: 5          item: 5573458    r_ui = None   est = 4.52   {'was_impossible': False}
# user: 5          item: 5582645    r_ui = None   est = 4.57   {'was_impossible': False}
# user: 5          item: 756267     r_ui = None   est = 4.74   {'was_impossible': False}
# user: 5          item: 5584157    r_ui = None   est = 4.31   {'was_impossible': False}
# user: 5          item: 765579     r_ui = None   est = 4.53   {'was_impossible': False}
# user: 5          item: 815685     r_ui = None   est = 3.93   {'was_impossible': False}
# user: 5          item: 819034     r_ui = None   est = 4.60   {'was_impossible': False}
# user: 5          item: 819044     r_ui = None   est = 4.25   {'was_impossible': False}
# user: 5          item: 5609608    r_ui = None   est = 4.44   {'was_impossible': False}
# user: 5          item: 833289     r_ui = None   est = 4.48   {'was_impossible': False}
# user: 5          item: 863139     r_ui = None   est = 4.41   {'was_impossible': False}
# user: 5          item: 881253     r_ui = None   est = 4.68   {'was_impossible': False}
# user: 5          item: 904378     r_ui = None   est = 4.75   {'was_impossible': False}
# user: 5          item: 5634851    r_ui = None   est = 4.42   {'was_impossible': False}
# user: 5          item: 5774164    r_ui = None   est = 4.14   {'was_impossible': False}
# user: 5          item: 5798211    r_ui = None   est = 4.59   {'was_impossible': False}
# user: 5          item: 915275     r_ui = None   est = 4.33   {'was_impossible': False}
# user: 5          item: 962594     r_ui = None   est = 4.34   {'was_impossible': False}
# user: 5          item: 982909     r_ui = None   est = 4.83   {'was_impossible': False}
# user: 5          item: 5827713    r_ui = None   est = 4.87   {'was_impossible': False}
# user: 5          item: 1024986    r_ui = None   est = 4.42   {'was_impossible': False}
# user: 5          item: 5827998    r_ui = None   est = 4.52   {'was_impossible': False}
# user: 5          item: 1160252    r_ui = None   est = 4.46   {'was_impossible': False}
# user: 5          item: 5889741    r_ui = None   est = 4.58   {'was_impossible': False}
# user: 5          item: 1261443    r_ui = None   est = 4.36   {'was_impossible': False}
# user: 5          item: 1363204    r_ui = None   est = 4.00   {'was_impossible': False}
# user: 5          item: 1495386    r_ui = None   est = 4.41   {'was_impossible': False}
# user: 5          item: 1508829    r_ui = None   est = 4.64   {'was_impossible': False}
# user: 5          item: 1615074    r_ui = None   est = 4.41   {'was_impossible': False}
# user: 5          item: 1654840    r_ui = None   est = 4.44   {'was_impossible': False}
# user: 5          item: 1678744    r_ui = None   est = 4.27   {'was_impossible': False}
# user: 5          item: 5908083    r_ui = None   est = 4.75   {'was_impossible': False}
# user: 5          item: 1678754    r_ui = None   est = 4.78   {'was_impossible': False}
# user: 5          item: 5919270    r_ui = None   est = 4.54   {'was_impossible': False}
# user: 5          item: 1678755    r_ui = None   est = 4.51   {'was_impossible': False}
# user: 5          item: 1902729    r_ui = None   est = 4.50   {'was_impossible': False}
# user: 5          item: 1902793    r_ui = None   est = 4.47   {'was_impossible': False}
# user: 5          item: 1941719    r_ui = None   est = 5.00   {'was_impossible': False}
# user: 5          item: 2009008    r_ui = None   est = 4.44   {'was_impossible': False}
# user: 5          item: 2030663    r_ui = None   est = 4.14   {'was_impossible': False}
# user: 5          item: 2129215    r_ui = None   est = 4.80   {'was_impossible': False}
# user: 5          item: 6020248    r_ui = None   est = 3.98   {'was_impossible': False}
# user: 5          item: 6261313    r_ui = None   est = 4.79   {'was_impossible': False}
# user: 5          item: 6287204    r_ui = None   est = 5.00   {'was_impossible': False}
# user: 5          item: 6300577    r_ui = None   est = 4.38   {'was_impossible': False}
# user: 5          item: 6317686    r_ui = None   est = 4.50   {'was_impossible': False}
# user: 5          item: 6453321    r_ui = None   est = 4.02   {'was_impossible': False}
# user: 5          item: 6481052    r_ui = None   est = 4.46   {'was_impossible': False}
# user: 5          item: 2142826    r_ui = None   est = 4.18   {'was_impossible': False}
# user: 5          item: 2156372    r_ui = None   est = 4.88   {'was_impossible': False}
# user: 5          item: 6529707    r_ui = None   est = 4.82   {'was_impossible': False}
# user: 5          item: 2320536    r_ui = None   est = 4.47   {'was_impossible': False}
# user: 5          item: 6547248    r_ui = None   est = 4.48   {'was_impossible': False}
# user: 5          item: 6603464    r_ui = None   est = 4.56   {'was_impossible': False}
# user: 5          item: 6620261    r_ui = None   est = 4.28   {'was_impossible': False}
# user: 5          item: 2387588    r_ui = None   est = 4.29   {'was_impossible': False}
# user: 5          item: 6630341    r_ui = None   est = 4.67   {'was_impossible': False}
# user: 5          item: 2387715    r_ui = None   est = 4.56   {'was_impossible': False}
# user: 5          item: 2387730    r_ui = None   est = 4.50   {'was_impossible': False}
# user: 5          item: 6638508    r_ui = None   est = 4.82   {'was_impossible': False}
# user: 5          item: 6693516    r_ui = None   est = 4.18   {'was_impossible': False}
# user: 5          item: 2922184    r_ui = None   est = 4.31   {'was_impossible': False}
# user: 5          item: 6716844    r_ui = None   est = 4.38   {'was_impossible': False}
# user: 5          item: 6718219    r_ui = None   est = 4.69   {'was_impossible': False}
# user: 5          item: 3034137    r_ui = None   est = 4.71   {'was_impossible': False}
# user: 5          item: 3075620    r_ui = None   est = 4.78   {'was_impossible': False}
# user: 5          item: 8277151    r_ui = None   est = 4.15   {'was_impossible': False}
# user: 5          item: 6718514    r_ui = None   est = 4.73   {'was_impossible': False}
# user: 5          item: 6831622    r_ui = None   est = 4.48   {'was_impossible': False}
# user: 5          item: 7156419    r_ui = None   est = 4.67   {'was_impossible': False}
# user: 5          item: 7162659    r_ui = None   est = 4.29   {'was_impossible': False}
# user: 5          item: 7250709    r_ui = None   est = 4.59   {'was_impossible': False}
# user: 5          item: 7250803    r_ui = None   est = 4.54   {'was_impossible': False}
# user: 5          item: 7296138    r_ui = None   est = 4.73   {'was_impossible': False}
# user: 5          item: 7321238    r_ui = None   est = 4.76   {'was_impossible': False}
# user: 5          item: 8343880    r_ui = None   est = 4.11   {'was_impossible': False}
# user: 5          item: 8345350    r_ui = None   est = 4.08   {'was_impossible': False}
# user: 5          item: 8345921    r_ui = None   est = 3.86   {'was_impossible': False}
# user: 5          item: 8355592    r_ui = None   est = 4.21   {'was_impossible': False}
# user: 5          item: 7398096    r_ui = None   est = 4.64   {'was_impossible': False}
# user: 5          item: 8380826    r_ui = None   est = 4.71   {'was_impossible': False}
# user: 5          item: 8445747    r_ui = None   est = 4.34   {'was_impossible': False}
# user: 5          item: 7441844    r_ui = None   est = 4.65   {'was_impossible': False}
# user: 5          item: 7641522    r_ui = None   est = 4.65   {'was_impossible': False}
# user: 5          item: 7653937    r_ui = None   est = 4.57   {'was_impossible': False}
# user: 5          item: 8508225    r_ui = None   est = 4.56   {'was_impossible': False}
# user: 5          item: 7666349    r_ui = None   est = 4.30   {'was_impossible': False}
# user: 5          item: 8625349    r_ui = None   est = 4.51   {'was_impossible': False}
# user: 5          item: 7667016    r_ui = None   est = 4.66   {'was_impossible': False}
# user: 5          item: 8626676    r_ui = None   est = 4.09   {'was_impossible': False}
# user: 5          item: 7720994    r_ui = None   est = 4.73   {'was_impossible': False}
# user: 5          item: 7765392    r_ui = None   est = 4.61   {'was_impossible': False}
# user: 5          item: 7769781    r_ui = None   est = 4.49   {'was_impossible': False}
# user: 5          item: 8654132    r_ui = None   est = 4.73   {'was_impossible': False}
# user: 5          item: 7905972    r_ui = None   est = 4.63   {'was_impossible': False}
# user: 5          item: 8654673    r_ui = None   est = 4.84   {'was_impossible': False}
# user: 5          item: 8705956    r_ui = None   est = 4.54   {'was_impossible': False}
# user: 5          item: 8721639    r_ui = None   est = 4.31   {'was_impossible': False}
# user: 5          item: 7927886    r_ui = None   est = 4.68   {'was_impossible': False}
# user: 5          item: 8800763    r_ui = None   est = 4.75   {'was_impossible': False}
# user: 5          item: 7946472    r_ui = None   est = 4.36   {'was_impossible': False}
# user: 5          item: 7994039    r_ui = None   est = 4.57   {'was_impossible': False}
# user: 5          item: 8004063    r_ui = None   est = 4.02   {'was_impossible': False}
# user: 5          item: 8007663    r_ui = None   est = 4.38   {'was_impossible': False}
# user: 5          item: 8017511    r_ui = None   est = 4.37   {'was_impossible': False}
# user: 5          item: 8038199    r_ui = None   est = 4.19   {'was_impossible': False}
# user: 5          item: 8061522    r_ui = None   est = 4.26   {'was_impossible': False}
# user: 5          item: 8111502    r_ui = None   est = 4.72   {'was_impossible': False}
# user: 5          item: 8111607    r_ui = None   est = 4.39   {'was_impossible': False}
# user: 5          item: 8113569    r_ui = None   est = 4.50   {'was_impossible': False}
# user: 5          item: 8113712    r_ui = None   est = 4.70   {'was_impossible': False}
# user: 5          item: 8113821    r_ui = None   est = 4.51   {'was_impossible': False}
# user: 5          item: 8113893    r_ui = None   est = 4.11   {'was_impossible': False}
# user: 5          item: 8113936    r_ui = None   est = 4.63   {'was_impossible': False}
# user: 5          item: 8114003    r_ui = None   est = 4.57   {'was_impossible': False}
# user: 5          item: 8180346    r_ui = None   est = 4.77   {'was_impossible': False}
# user: 5          item: 8195397    r_ui = None   est = 3.97   {'was_impossible': False}
# user: 5          item: 8196180    r_ui = None   est = 4.06   {'was_impossible': False}
# user: 5          item: 8196359    r_ui = None   est = 3.76   {'was_impossible': False}
# user: 5          item: 8196417    r_ui = None   est = 4.72   {'was_impossible': False}
# user: 5          item: 8200542    r_ui = None   est = 4.62   {'was_impossible': False}
# user: 5          item: 8890247    r_ui = None   est = 3.86   {'was_impossible': False}
# user: 5          item: 8212422    r_ui = None   est = 4.42   {'was_impossible': False}
# user: 5          item: 8256942    r_ui = None   est = 4.35   {'was_impossible': False}
# user: 5          item: 8264717    r_ui = None   est = 4.59   {'was_impossible': False}
# user: 5          item: 8897560    r_ui = None   est = 3.99   {'was_impossible': False}
# user: 5          item: 8914905    r_ui = None   est = 4.51   {'was_impossible': False}
# user: 5          item: 9016784    r_ui = None   est = 4.18   {'was_impossible': False}
# user: 5          item: 9054629    r_ui = None   est = 4.82   {'was_impossible': False}
# user: 5          item: 9054941    r_ui = None   est = 4.39   {'was_impossible': False}
# user: 5          item: 9055103    r_ui = None   est = 4.67   {'was_impossible': False}
# user: 5          item: 9116730    r_ui = None   est = 4.48   {'was_impossible': False}
# user: 5          item: 9986864    r_ui = None   est = 4.31   {'was_impossible': False}
# user: 5          item: 10001615   r_ui = None   est = 4.30   {'was_impossible': False}
# user: 5          item: 10020525   r_ui = None   est = 4.40   {'was_impossible': False}
# user: 5          item: 10020690   r_ui = None   est = 4.45   {'was_impossible': False}
# user: 5          item: 10021140   r_ui = None   est = 3.90   {'was_impossible': False}
# user: 5          item: 9143024    r_ui = None   est = 4.02   {'was_impossible': False}
# user: 5          item: 10021610   r_ui = None   est = 3.78   {'was_impossible': False}
# user: 5          item: 9216943    r_ui = None   est = 4.61   {'was_impossible': False}
# user: 5          item: 10023519   r_ui = None   est = 4.35   {'was_impossible': False}
# user: 5          item: 9268058    r_ui = None   est = 4.43   {'was_impossible': False}
# user: 5          item: 10027442   r_ui = None   est = 4.42   {'was_impossible': False}
# user: 5          item: 9268500    r_ui = None   est = 3.66   {'was_impossible': False}
# user: 5          item: 10030323   r_ui = None   est = 4.52   {'was_impossible': False}
# user: 5          item: 9268680    r_ui = None   est = 4.66   {'was_impossible': False}
# user: 5          item: 9269260    r_ui = None   est = 4.40   {'was_impossible': False}
# user: 5          item: 9269637    r_ui = None   est = 4.62   {'was_impossible': False}
# user: 5          item: 9269848    r_ui = None   est = 4.60   {'was_impossible': False}
# user: 5          item: 9269981    r_ui = None   est = 4.36   {'was_impossible': False}
# user: 5          item: 9281075    r_ui = None   est = 4.76   {'was_impossible': False}
# user: 5          item: 10032227   r_ui = None   est = 4.30   {'was_impossible': False}
# user: 5          item: 10040456   r_ui = None   est = 4.03   {'was_impossible': False}
# user: 5          item: 9283072    r_ui = None   est = 3.79   {'was_impossible': False}
# user: 5          item: 10040969   r_ui = None   est = 4.10   {'was_impossible': False}
# user: 5          item: 9351647    r_ui = None   est = 4.62   {'was_impossible': False}
# user: 5          item: 10041012   r_ui = None   est = 3.94   {'was_impossible': False}
# user: 5          item: 9464059    r_ui = None   est = 4.34   {'was_impossible': False}
# user: 5          item: 10126030   r_ui = None   est = 4.22   {'was_impossible': False}
# user: 5          item: 10399199   r_ui = None   est = 4.73   {'was_impossible': False}
# user: 5          item: 10427701   r_ui = None   est = 4.42   {'was_impossible': False}
# user: 5          item: 10466406   r_ui = None   est = 3.15   {'was_impossible': False}
# user: 5          item: 10626378   r_ui = None   est = 4.06   {'was_impossible': False}
# user: 5          item: 10718463   r_ui = None   est = 4.20   {'was_impossible': False}
# user: 5          item: 9476931    r_ui = None   est = 4.14   {'was_impossible': False}
# user: 5          item: 11071722   r_ui = None   est = 4.27   {'was_impossible': False}
# user: 5          item: 11127543   r_ui = None   est = 3.79   {'was_impossible': False}
# user: 5          item: 9532788    r_ui = None   est = 4.88   {'was_impossible': False}
# user: 5          item: 11262375   r_ui = None   est = 4.71   {'was_impossible': False}
# user: 5          item: 11425553   r_ui = None   est = 4.78   {'was_impossible': False}
# user: 5          item: 11465411   r_ui = None   est = 4.47   {'was_impossible': False}
# user: 5          item: 11496278   r_ui = None   est = 4.45   {'was_impossible': False}
# user: 5          item: 9584573    r_ui = None   est = 4.46   {'was_impossible': False}
# user: 5          item: 9635192    r_ui = None   est = 4.60   {'was_impossible': False}
# user: 5          item: 11544732   r_ui = None   est = 4.50   {'was_impossible': False}
# user: 5          item: 11581560   r_ui = None   est = 4.72   {'was_impossible': False}
# user: 5          item: 11660178   r_ui = None   est = 4.61   {'was_impossible': False}
# user: 5          item: 11679463   r_ui = None   est = 4.20   {'was_impossible': False}
# user: 5          item: 11760026   r_ui = None   est = 4.48   {'was_impossible': False}
# user: 5          item: 11863888   r_ui = None   est = 4.55   {'was_impossible': False}
# user: 5          item: 11865360   r_ui = None   est = 4.31   {'was_impossible': False}
# user: 5          item: 11980197   r_ui = None   est = 4.88   {'was_impossible': False}
# user: 5          item: 11993987   r_ui = None   est = 3.56   {'was_impossible': False}
# user: 5          item: 12028422   r_ui = None   est = 4.31   {'was_impossible': False}
# user: 5          item: 12162272   r_ui = None   est = 4.88   {'was_impossible': False}
# user: 5          item: 9637478    r_ui = None   est = 4.09   {'was_impossible': False}
# user: 5          item: 9683612    r_ui = None   est = 3.96   {'was_impossible': False}
# user: 5          item: 9746208    r_ui = None   est = 4.78   {'was_impossible': False}
# user: 5          item: 12211385   r_ui = None   est = 4.25   {'was_impossible': False}
# user: 5          item: 9857050    r_ui = None   est = 4.46   {'was_impossible': False}
# user: 5          item: 12211392   r_ui = None   est = 4.41   {'was_impossible': False}
# user: 5          item: 9866985    r_ui = None   est = 3.97   {'was_impossible': False}
# user: 5          item: 12213801   r_ui = None   est = 4.64   {'was_impossible': False}
# user: 5          item: 12219588   r_ui = None   est = 4.51   {'was_impossible': False}
# user: 5          item: 9887900    r_ui = None   est = 4.14   {'was_impossible': False}
# user: 5          item: 9910891    r_ui = None   est = 4.68   {'was_impossible': False}
# user: 5          item: 12317780   r_ui = None   est = 4.41   {'was_impossible': False}
# user: 5          item: 9928008    r_ui = None   est = 4.53   {'was_impossible': False}
# user: 5          item: 12345284   r_ui = None   est = 4.39   {'was_impossible': False}
# user: 5          item: 9932692    r_ui = None   est = 3.99   {'was_impossible': False}
# user: 5          item: 12347038   r_ui = None   est = 4.42   {'was_impossible': False}
# user: 5          item: 9967697    r_ui = None   est = 3.52   {'was_impossible': False}
# user: 5          item: 12434512   r_ui = None   est = 4.61   {'was_impossible': False}
# user: 5          item: 12455215   r_ui = None   est = 3.94   {'was_impossible': False}
# user: 5          item: 12366660   r_ui = None   est = 4.18   {'was_impossible': False}
# user: 5          item: 12366958   r_ui = None   est = 4.72   {'was_impossible': False}
# user: 5          item: 12484261   r_ui = None   est = 4.88   {'was_impossible': False}
# user: 5          item: 12367042   r_ui = None   est = 4.11   {'was_impossible': False}
# user: 5          item: 12367245   r_ui = None   est = 3.95   {'was_impossible': False}
# user: 5          item: 12367388   r_ui = None   est = 3.88   {'was_impossible': False}
# user: 5          item: 12556334   r_ui = None   est = 4.63   {'was_impossible': False}
# user: 5          item: 12702541   r_ui = None   est = 4.98   {'was_impossible': False}
# user: 5          item: 12710735   r_ui = None   est = 4.18   {'was_impossible': False}
# user: 5          item: 12738797   r_ui = None   est = 4.76   {'was_impossible': False}
# user: 5          item: 14407337   r_ui = None   est = 4.52   {'was_impossible': False}
# user: 5          item: 14435012   r_ui = None   est = 4.38   {'was_impossible': False}
# user: 5          item: 14489603   r_ui = None   est = 4.23   {'was_impossible': False}
# user: 5          item: 12738896   r_ui = None   est = 4.72   {'was_impossible': False}
# user: 5          item: 12801097   r_ui = None   est = 4.19   {'was_impossible': False}
# user: 5          item: 12904788   r_ui = None   est = 4.64   {'was_impossible': False}
# user: 5          item: 14530157   r_ui = None   est = 4.93   {'was_impossible': False}
# user: 5          item: 12975156   r_ui = None   est = 4.75   {'was_impossible': False}
# user: 5          item: 12975736   r_ui = None   est = 4.63   {'was_impossible': False}
# user: 5          item: 13049120   r_ui = None   est = 4.27   {'was_impossible': False}
# user: 5          item: 14577360   r_ui = None   est = 4.68   {'was_impossible': False}
# user: 5          item: 14582945   r_ui = None   est = 4.62   {'was_impossible': False}
# user: 5          item: 13183241   r_ui = None   est = 4.57   {'was_impossible': False}
# user: 5          item: 13243736   r_ui = None   est = 4.49   {'was_impossible': False}
# user: 5          item: 14583967   r_ui = None   est = 4.25   {'was_impossible': False}
# user: 5          item: 14701395   r_ui = None   est = 4.49   {'was_impossible': False}
# user: 5          item: 13254555   r_ui = None   est = 4.46   {'was_impossible': False}
# user: 5          item: 14901562   r_ui = None   est = 4.33   {'was_impossible': False}
# user: 5          item: 13274269   r_ui = None   est = 4.15   {'was_impossible': False}
# user: 5          item: 14902239   r_ui = None   est = 4.56   {'was_impossible': False}
# user: 5          item: 14926743   r_ui = None   est = 4.72   {'was_impossible': False}
# user: 5          item: 13274598   r_ui = None   est = 4.07   {'was_impossible': False}
# user: 5          item: 13283938   r_ui = None   est = 4.64   {'was_impossible': False}
# user: 5          item: 14953906   r_ui = None   est = 4.59   {'was_impossible': False}
# user: 5          item: 15100514   r_ui = None   est = 4.46   {'was_impossible': False}
# user: 5          item: 15274648   r_ui = None   est = 4.63   {'was_impossible': False}
# user: 5          item: 15310627   r_ui = None   est = 4.83   {'was_impossible': False}
# user: 5          item: 15316856   r_ui = None   est = 4.73   {'was_impossible': False}
# user: 5          item: 15364942   r_ui = None   est = 4.56   {'was_impossible': False}
# user: 5          item: 15367409   r_ui = None   est = 4.05   {'was_impossible': False}
# user: 5          item: 13286282   r_ui = None   est = 4.55   {'was_impossible': False}
# user: 5          item: 15389076   r_ui = None   est = 4.61   {'was_impossible': False}
# user: 5          item: 13317120   r_ui = None   est = 4.54   {'was_impossible': False}
# user: 5          item: 15406706   r_ui = None   est = 4.41   {'was_impossible': False}
# user: 5          item: 15428715   r_ui = None   est = 4.53   {'was_impossible': False}
# user: 5          item: 13335962   r_ui = None   est = 3.78   {'was_impossible': False}
# user: 5          item: 13336133   r_ui = None   est = 4.07   {'was_impossible': False}
# user: 5          item: 15441196   r_ui = None   est = 4.44   {'was_impossible': False}
# user: 5          item: 15454153   r_ui = None   est = 4.49   {'was_impossible': False}
# user: 5          item: 13396802   r_ui = None   est = 4.08   {'was_impossible': False}
# user: 5          item: 13454638   r_ui = None   est = 4.13   {'was_impossible': False}
# user: 5          item: 13468399   r_ui = None   est = 4.45   {'was_impossible': False}
# user: 5          item: 15487894   r_ui = None   est = 4.35   {'was_impossible': False}
# user: 5          item: 15492056   r_ui = None   est = 3.95   {'was_impossible': False}
# user: 5          item: 13556435   r_ui = None   est = 4.85   {'was_impossible': False}
# user: 5          item: 15508557   r_ui = None   est = 4.70   {'was_impossible': False}
# user: 5          item: 15538540   r_ui = None   est = 4.41   {'was_impossible': False}
# user: 5          item: 13559548   r_ui = None   est = 4.34   {'was_impossible': False}
# user: 5          item: 15619288   r_ui = None   est = 4.49   {'was_impossible': False}
# user: 5          item: 13566223   r_ui = None   est = 4.59   {'was_impossible': False}
# user: 5          item: 13642646   r_ui = None   est = 4.69   {'was_impossible': False}
# user: 5          item: 13703898   r_ui = None   est = 4.31   {'was_impossible': False}
# user: 5          item: 13717530   r_ui = None   est = 4.32   {'was_impossible': False}
# user: 5          item: 15687109   r_ui = None   est = 4.43   {'was_impossible': False}
# user: 5          item: 15727280   r_ui = None   est = 4.31   {'was_impossible': False}
# user: 5          item: 13809823   r_ui = None   est = 4.34   {'was_impossible': False}
# user: 5          item: 15773382   r_ui = None   est = 4.54   {'was_impossible': False}
# user: 5          item: 15775439   r_ui = None   est = 4.43   {'was_impossible': False}
# user: 5          item: 15792137   r_ui = None   est = 4.33   {'was_impossible': False}
# user: 5          item: 13817559   r_ui = None   est = 4.38   {'was_impossible': False}
# user: 5          item: 13952292   r_ui = None   est = 4.55   {'was_impossible': False}
# user: 5          item: 13965663   r_ui = None   est = 4.18   {'was_impossible': False}
# user: 5          item: 13967760   r_ui = None   est = 4.20   {'was_impossible': False}
# user: 5          item: 14020127   r_ui = None   est = 4.48   {'was_impossible': False}
# user: 5          item: 14029416   r_ui = None   est = 4.54   {'was_impossible': False}
# user: 5          item: 14094341   r_ui = None   est = 4.54   {'was_impossible': False}
# user: 5          item: 14099732   r_ui = None   est = 4.44   {'was_impossible': False}
# user: 5          item: 14131949   r_ui = None   est = 4.64   {'was_impossible': False}
# user: 5          item: 14211027   r_ui = None   est = 4.64   {'was_impossible': False}
# user: 5          item: 14226426   r_ui = None   est = 4.76   {'was_impossible': False}
# user: 5          item: 14226658   r_ui = None   est = 4.73   {'was_impossible': False}
# user: 5          item: 15792808   r_ui = None   est = 4.51   {'was_impossible': False}
# user: 5          item: 14245740   r_ui = None   est = 4.73   {'was_impossible': False}
# user: 5          item: 15813099   r_ui = None   est = 4.30   {'was_impossible': False}
# user: 5          item: 15918822   r_ui = None   est = 4.35   {'was_impossible': False}
# user: 5          item: 15919067   r_ui = None   est = 4.13   {'was_impossible': False}
# user: 5          item: 15919162   r_ui = None   est = 3.85   {'was_impossible': False}
# user: 5          item: 15933531   r_ui = None   est = 4.21   {'was_impossible': False}
# user: 5          item: 15965563   r_ui = None   est = 4.41   {'was_impossible': False}
# user: 5          item: 15978100   r_ui = None   est = 3.79   {'was_impossible': False}
# user: 5          item: 15991345   r_ui = None   est = 4.20   {'was_impossible': False}
# user: 5          item: 16006904   r_ui = None   est = 4.69   {'was_impossible': False}
# user: 5          item: 16007139   r_ui = None   est = 4.31   {'was_impossible': False}
# user: 5          item: 16008908   r_ui = None   est = 4.54   {'was_impossible': False}
# user: 5          item: 16036564   r_ui = None   est = 4.62   {'was_impossible': False}
# user: 5          item: 16044788   r_ui = None   est = 5.00   {'was_impossible': False}
# user: 5          item: 16057988   r_ui = None   est = 4.41   {'was_impossible': False}
# user: 5          item: 14289091   r_ui = None   est = 4.51   {'was_impossible': False}
# user: 5          item: 14315372   r_ui = None   est = 4.59   {'was_impossible': False}
# user: 5          item: 14332483   r_ui = None   est = 4.52   {'was_impossible': False}
# user: 5          item: 14341511   r_ui = None   est = 4.73   {'was_impossible': False}
# user: 5          item: 16110969   r_ui = None   est = 4.10   {'was_impossible': False}
# user: 5          item: 16118606   r_ui = None   est = 4.76   {'was_impossible': False}
# user: 5          item: 16140165   r_ui = None   est = 4.32   {'was_impossible': False}
# user: 5          item: 16149105   r_ui = None   est = 4.48   {'was_impossible': False}
# user: 5          item: 17191773   r_ui = None   est = 4.58   {'was_impossible': False}
# user: 5          item: 17275135   r_ui = None   est = 4.29   {'was_impossible': False}
# user: 5          item: 16150227   r_ui = None   est = 4.52   {'was_impossible': False}
# user: 5          item: 16150642   r_ui = None   est = 4.63   {'was_impossible': False}
# user: 5          item: 16177101   r_ui = None   est = 4.17   {'was_impossible': False}
# user: 5          item: 17414394   r_ui = None   est = 3.94   {'was_impossible': False}
# user: 5          item: 17454856   r_ui = None   est = 4.16   {'was_impossible': False}
# user: 5          item: 16183428   r_ui = None   est = 4.36   {'was_impossible': False}
# user: 5          item: 17483368   r_ui = None   est = 4.62   {'was_impossible': False}
# user: 5          item: 16209070   r_ui = None   est = 4.52   {'was_impossible': False}
# user: 5          item: 17488373   r_ui = None   est = 4.42   {'was_impossible': False}
# user: 5          item: 17519803   r_ui = None   est = 4.32   {'was_impossible': False}
# user: 5          item: 17601150   r_ui = None   est = 4.96   {'was_impossible': False}
# user: 5          item: 16213115   r_ui = None   est = 3.30   {'was_impossible': False}
# user: 5          item: 17615250   r_ui = None   est = 4.43   {'was_impossible': False}
# user: 5          item: 17626886   r_ui = None   est = 4.59   {'was_impossible': False}
# user: 5          item: 17641382   r_ui = None   est = 4.84   {'was_impossible': False}
# user: 5          item: 16220808   r_ui = None   est = 4.43   {'was_impossible': False}
# user: 5          item: 16260783   r_ui = None   est = 4.23   {'was_impossible': False}
# user: 5          item: 17672050   r_ui = None   est = 3.67   {'was_impossible': False}
# user: 5          item: 16309636   r_ui = None   est = 4.82   {'was_impossible': False}
# user: 5          item: 17684352   r_ui = None   est = 4.69   {'was_impossible': False}
# user: 5          item: 16370834   r_ui = None   est = 4.68   {'was_impossible': False}
# user: 5          item: 17736530   r_ui = None   est = 4.76   {'was_impossible': False}
# user: 5          item: 17740089   r_ui = None   est = 3.84   {'was_impossible': False}
# user: 5          item: 17766467   r_ui = None   est = 4.61   {'was_impossible': False}
# user: 5          item: 16411791   r_ui = None   est = 4.57   {'was_impossible': False}
# user: 5          item: 17769862   r_ui = None   est = 4.57   {'was_impossible': False}
# user: 5          item: 16424205   r_ui = None   est = 4.53   {'was_impossible': False}
# user: 5          item: 16427874   r_ui = None   est = 4.58   {'was_impossible': False}
# user: 5          item: 16428014   r_ui = None   est = 4.22   {'was_impossible': False}
# user: 5          item: 17778761   r_ui = None   est = 4.05   {'was_impossible': False}
# user: 5          item: 17868078   r_ui = None   est = 4.41   {'was_impossible': False}
# user: 5          item: 16429519   r_ui = None   est = 4.40   {'was_impossible': False}
# user: 5          item: 17881638   r_ui = None   est = 3.72   {'was_impossible': False}
# user: 5          item: 17884419   r_ui = None   est = 4.36   {'was_impossible': False}
# user: 5          item: 17927897   r_ui = None   est = 4.77   {'was_impossible': False}
# user: 5          item: 16462052   r_ui = None   est = 4.57   {'was_impossible': False}
# user: 5          item: 16477283   r_ui = None   est = 4.62   {'was_impossible': False}
# user: 5          item: 17928170   r_ui = None   est = 4.44   {'was_impossible': False}
# user: 5          item: 16502098   r_ui = None   est = 4.80   {'was_impossible': False}
# user: 5          item: 16519375   r_ui = None   est = 4.49   {'was_impossible': False}
# user: 5          item: 16522880   r_ui = None   est = 3.57   {'was_impossible': False}
# user: 5          item: 16524551   r_ui = None   est = 4.63   {'was_impossible': False}
# user: 5          item: 16552273   r_ui = None   est = 4.34   {'was_impossible': False}
# user: 5          item: 17928273   r_ui = None   est = 4.55   {'was_impossible': False}
# user: 5          item: 16565287   r_ui = None   est = 4.51   {'was_impossible': False}
# user: 5          item: 16621264   r_ui = None   est = 4.32   {'was_impossible': False}
# user: 5          item: 16650721   r_ui = None   est = 4.46   {'was_impossible': False}
# user: 5          item: 17929045   r_ui = None   est = 4.54   {'was_impossible': False}
# user: 5          item: 16677104   r_ui = None   est = 4.51   {'was_impossible': False}
# user: 5          item: 16701352   r_ui = None   est = 4.81   {'was_impossible': False}
# user: 5          item: 17929049   r_ui = None   est = 4.41   {'was_impossible': False}
# user: 5          item: 17929053   r_ui = None   est = 4.37   {'was_impossible': False}
# user: 5          item: 16742820   r_ui = None   est = 4.39   {'was_impossible': False}
# user: 5          item: 17929054   r_ui = None   est = 4.51   {'was_impossible': False}
# user: 5          item: 17929055   r_ui = None   est = 4.68   {'was_impossible': False}
# user: 5          item: 17949590   r_ui = None   est = 4.48   {'was_impossible': False}
# user: 5          item: 16743909   r_ui = None   est = 4.75   {'was_impossible': False}
# user: 5          item: 17951810   r_ui = None   est = 4.75   {'was_impossible': False}
# user: 5          item: 18000521   r_ui = None   est = 4.11   {'was_impossible': False}
# user: 5          item: 18052476   r_ui = None   est = 4.65   {'was_impossible': False}
# user: 5          item: 16744167   r_ui = None   est = 4.48   {'was_impossible': False}
# user: 5          item: 18109887   r_ui = None   est = 4.76   {'was_impossible': False}
# user: 5          item: 16745292   r_ui = None   est = 3.59   {'was_impossible': False}
# user: 5          item: 18151459   r_ui = None   est = 4.42   {'was_impossible': False}
# user: 5          item: 18166182   r_ui = None   est = 4.10   {'was_impossible': False}
# user: 5          item: 16750061   r_ui = None   est = 4.57   {'was_impossible': False}
# user: 5          item: 16758638   r_ui = None   est = 4.68   {'was_impossible': False}
# user: 5          item: 18169687   r_ui = None   est = 4.62   {'was_impossible': False}
# user: 5          item: 18184250   r_ui = None   est = 4.10   {'was_impossible': False}
# user: 5          item: 16846533   r_ui = None   est = 4.70   {'was_impossible': False}
# user: 5          item: 16848828   r_ui = None   est = 3.74   {'was_impossible': False}
# user: 5          item: 16881298   r_ui = None   est = 4.03   {'was_impossible': False}
# user: 5          item: 16891958   r_ui = None   est = 4.65   {'was_impossible': False}
# user: 5          item: 16964241   r_ui = None   est = 4.43   {'was_impossible': False}
# user: 5          item: 18199481   r_ui = None   est = 4.76   {'was_impossible': False}
# user: 5          item: 16966634   r_ui = None   est = 4.85   {'was_impossible': False}
# user: 5          item: 18202395   r_ui = None   est = 4.82   {'was_impossible': False}
# user: 5          item: 18235755   r_ui = None   est = 4.60   {'was_impossible': False}
# user: 5          item: 16985394   r_ui = None   est = 4.35   {'was_impossible': False}
# user: 5          item: 17016908   r_ui = None   est = 4.44   {'was_impossible': False}
# user: 5          item: 17053896   r_ui = None   est = 4.09   {'was_impossible': False}
# user: 5          item: 17110437   r_ui = None   est = 4.57   {'was_impossible': False}
# user: 5          item: 17179470   r_ui = None   est = 4.63   {'was_impossible': False}
# user: 5          item: 18905203   r_ui = None   est = 4.85   {'was_impossible': False}
# user: 5          item: 19056267   r_ui = None   est = 4.41   {'was_impossible': False}
# user: 5          item: 19107598   r_ui = None   est = 4.74   {'was_impossible': False}
# user: 5          item: 19200431   r_ui = None   est = 4.13   {'was_impossible': False}
# user: 5          item: 19218794   r_ui = None   est = 4.81   {'was_impossible': False}
# user: 5          item: 19231371   r_ui = None   est = 4.30   {'was_impossible': False}
# user: 5          item: 19351097   r_ui = None   est = 4.70   {'was_impossible': False}
# user: 5          item: 19595322   r_ui = None   est = 4.59   {'was_impossible': False}
# user: 5          item: 18253219   r_ui = None   est = 4.36   {'was_impossible': False}
# user: 5          item: 18286281   r_ui = None   est = 4.77   {'was_impossible': False}
# user: 5          item: 19595827   r_ui = None   est = 4.49   {'was_impossible': False}
# user: 5          item: 18388608   r_ui = None   est = 4.62   {'was_impossible': False}
# user: 5          item: 19648215   r_ui = None   est = 3.87   {'was_impossible': False}
# user: 5          item: 19652882   r_ui = None   est = 3.84   {'was_impossible': False}
# user: 5          item: 19720477   r_ui = None   est = 4.56   {'was_impossible': False}
# user: 5          item: 19731540   r_ui = None   est = 4.49   {'was_impossible': False}
# user: 5          item: 19774490   r_ui = None   est = 4.55   {'was_impossible': False}
# user: 5          item: 19801431   r_ui = None   est = 4.48   {'was_impossible': False}
# user: 5          item: 19831199   r_ui = None   est = 4.70   {'was_impossible': False}
# user: 5          item: 18421322   r_ui = None   est = 4.49   {'was_impossible': False}
# user: 5          item: 18434466   r_ui = None   est = 4.71   {'was_impossible': False}
# user: 5          item: 18452100   r_ui = None   est = 4.52   {'was_impossible': False}
# user: 5          item: 18484277   r_ui = None   est = 4.76   {'was_impossible': False}
# user: 5          item: 18508828   r_ui = None   est = 4.76   {'was_impossible': False}
# user: 5          item: 19847774   r_ui = None   est = 4.12   {'was_impossible': False}
# user: 5          item: 19895150   r_ui = None   est = 4.57   {'was_impossible': False}
# user: 5          item: 20016031   r_ui = None   est = 4.34   {'was_impossible': False}
# user: 5          item: 18513959   r_ui = None   est = 4.59   {'was_impossible': False}
# user: 5          item: 20016671   r_ui = None   est = 4.70   {'was_impossible': False}
# user: 5          item: 18585234   r_ui = None   est = 4.70   {'was_impossible': False}
# user: 5          item: 20065234   r_ui = None   est = 4.71   {'was_impossible': False}
# user: 5          item: 18619859   r_ui = None   est = 4.62   {'was_impossible': False}
# user: 5          item: 20084815   r_ui = None   est = 4.91   {'was_impossible': False}
# user: 5          item: 18674998   r_ui = None   est = 4.51   {'was_impossible': False}
# user: 5          item: 20096441   r_ui = None   est = 4.33   {'was_impossible': False}
# user: 5          item: 20181595   r_ui = None   est = 3.86   {'was_impossible': False}
# user: 5          item: 20181944   r_ui = None   est = 4.54   {'was_impossible': False}
# user: 5          item: 20182075   r_ui = None   est = 4.73   {'was_impossible': False}
# user: 5          item: 20395120   r_ui = None   est = 4.52   {'was_impossible': False}
# user: 5          item: 18675202   r_ui = None   est = 4.58   {'was_impossible': False}
# user: 5          item: 20468114   r_ui = None   est = 3.68   {'was_impossible': False}
# user: 5          item: 20512779   r_ui = None   est = 4.75   {'was_impossible': False}
# user: 5          item: 18858584   r_ui = None   est = 4.79   {'was_impossible': False}
# user: 5          item: 18899288   r_ui = None   est = 4.33   {'was_impossible': False}
# user: 5          item: 20539655   r_ui = None   est = 4.45   {'was_impossible': False}
# user: 5          item: 20904654   r_ui = None   est = 4.06   {'was_impossible': False}
# user: 5          item: 20625726   r_ui = None   est = 4.45   {'was_impossible': False}
# user: 5          item: 20625773   r_ui = None   est = 4.44   {'was_impossible': False}
# user: 5          item: 21013726   r_ui = None   est = 4.07   {'was_impossible': False}
# user: 5          item: 20659099   r_ui = None   est = 4.14   {'was_impossible': False}
# user: 5          item: 20772493   r_ui = None   est = 4.28   {'was_impossible': False}
# user: 5          item: 20774303   r_ui = None   est = 3.73   {'was_impossible': False}
# user: 5          item: 20774607   r_ui = None   est = 4.51   {'was_impossible': False}
# user: 5          item: 20778113   r_ui = None   est = 4.39   {'was_impossible': False}
# user: 5          item: 20791161   r_ui = None   est = 4.60   {'was_impossible': False}
# user: 5          item: 20803693   r_ui = None   est = 4.05   {'was_impossible': False}
# user: 5          item: 20806898   r_ui = None   est = 4.48   {'was_impossible': False}
# user: 5          item: 20824274   r_ui = None   est = 4.58   {'was_impossible': False}
# user: 5          item: 21015824   r_ui = None   est = 4.47   {'was_impossible': False}
# user: 5          item: 20877332   r_ui = None   est = 3.95   {'was_impossible': False}
# user: 5          item: 20888336   r_ui = None   est = 4.91   {'was_impossible': False}
# user: 5          item: 21015873   r_ui = None   est = 4.69   {'was_impossible': False}
# user: 5          item: 21015874   r_ui = None   est = 4.41   {'was_impossible': False}
# user: 5          item: 21015876   r_ui = None   est = 4.53   {'was_impossible': False}
# user: 5          item: 21015880   r_ui = None   est = 4.65   {'was_impossible': False}
# user: 5          item: 21015881   r_ui = None   est = 4.50   {'was_impossible': False}
# user: 5          item: 22214451   r_ui = None   est = 4.47   {'was_impossible': False}
# user: 5          item: 21015977   r_ui = None   est = 4.74   {'was_impossible': False}
# user: 5          item: 22233862   r_ui = None   est = 4.78   {'was_impossible': False}
# user: 5          item: 21037930   r_ui = None   est = 4.53   {'was_impossible': False}
# user: 5          item: 21154124   r_ui = None   est = 4.49   {'was_impossible': False}
# user: 5          item: 21200260   r_ui = None   est = 4.63   {'was_impossible': False}
# user: 5          item: 22267147   r_ui = None   est = 4.32   {'was_impossible': False}
# user: 5          item: 21283595   r_ui = None   est = 4.21   {'was_impossible': False}
# user: 5          item: 21358634   r_ui = None   est = 4.03   {'was_impossible': False}
# user: 5          item: 22345943   r_ui = None   est = 4.45   {'was_impossible': False}
# user: 5          item: 22348216   r_ui = None   est = 3.92   {'was_impossible': False}
# user: 5          item: 22376153   r_ui = None   est = 4.46   {'was_impossible': False}
# user: 5          item: 22395492   r_ui = None   est = 4.64   {'was_impossible': False}
# user: 5          item: 21370642   r_ui = None   est = 4.95   {'was_impossible': False}
# user: 5          item: 21402272   r_ui = None   est = 4.21   {'was_impossible': False}
# user: 5          item: 22469925   r_ui = None   est = 3.97   {'was_impossible': False}
# user: 5          item: 21415749   r_ui = None   est = 4.88   {'was_impossible': False}
# user: 5          item: 22544362   r_ui = None   est = 4.74   {'was_impossible': False}
# user: 5          item: 22561172   r_ui = None   est = 4.72   {'was_impossible': False}
# user: 5          item: 22577896   r_ui = None   est = 4.08   {'was_impossible': False}
# user: 5          item: 22588306   r_ui = None   est = 4.24   {'was_impossible': False}
# user: 5          item: 22594189   r_ui = None   est = 4.43   {'was_impossible': False}
# user: 5          item: 22627321   r_ui = None   est = 3.74   {'was_impossible': False}
# user: 5          item: 22666446   r_ui = None   est = 4.43   {'was_impossible': False}
# user: 5          item: 21416331   r_ui = None   est = 4.47   {'was_impossible': False}
# user: 5          item: 21416445   r_ui = None   est = 4.43   {'was_impossible': False}
# user: 5          item: 21419965   r_ui = None   est = 4.45   {'was_impossible': False}
# user: 5          item: 21420790   r_ui = None   est = 4.18   {'was_impossible': False}
# user: 5          item: 21428446   r_ui = None   est = 4.35   {'was_impossible': False}
# user: 5          item: 22733377   r_ui = None   est = 4.32   {'was_impossible': False}
# user: 5          item: 22745179   r_ui = None   est = 4.71   {'was_impossible': False}
# user: 5          item: 21462227   r_ui = None   est = 4.41   {'was_impossible': False}
# user: 5          item: 21552874   r_ui = None   est = 4.39   {'was_impossible': False}
# ...
# user: 5          item: 807517790122516068 r_ui = None   est = 3.81   {'was_impossible': False}
# user: 5          item: 810376811309754844 r_ui = None   est = 4.61   {'was_impossible': False}
# user: 5          item: 791220299796324757 r_ui = None   est = 4.59   {'was_impossible': False}
# user: 5          item: 791827163601709023 r_ui = None   est = 4.25   {'was_impossible': False}
# user: 5          item: 791849721681232177 r_ui = None   est = 3.55   {'was_impossible': False}
# user: 5          item: 791860562256839256 r_ui = None   est = 3.94   {'was_impossible': False}
# user: 5          item: 792603247459994158 r_ui = None   est = 4.39   {'was_impossible': False}
# user: 5          item: 793166480609239891 r_ui = None   est = 4.32   {'was_impossible': False}
# user: 5          item: 819865960419314544 r_ui = None   est = 4.36   {'was_impossible': False}
# user: 5          item: 795604418544657614 r_ui = None   est = 4.74   {'was_impossible': False}
# user: 5          item: 795610316764755392 r_ui = None   est = 4.65   {'was_impossible': False}
# user: 5          item: 796914308659700324 r_ui = None   est = 3.87   {'was_impossible': False}
# user: 5          item: 797803174723261219 r_ui = None   est = 4.51   {'was_impossible': False}
# user: 5          item: 820231423212934260 r_ui = None   est = 3.89   {'was_impossible': False}
# user: 5          item: 822059164708734993 r_ui = None   est = 4.56   {'was_impossible': False}
# user: 5          item: 797803349923891890 r_ui = None   est = 4.40   {'was_impossible': False}
# user: 5          item: 797803469013947014 r_ui = None   est = 4.43   {'was_impossible': False}
# user: 5          item: 797803598869629444 r_ui = None   est = 4.62   {'was_impossible': False}
# user: 5          item: 825579456713831810 r_ui = None   est = 4.48   {'was_impossible': False}
# user: 5          item: 829699288462514983 r_ui = None   est = 4.22   {'was_impossible': False}
# user: 5          item: 825592428687196191 r_ui = None   est = 4.55   {'was_impossible': False}
# user: 5          item: 826103426321164128 r_ui = None   est = 4.43   {'was_impossible': False}
# user: 5          item: 830802771232450169 r_ui = None   est = 4.55   {'was_impossible': False}
# user: 5          item: 827845795285182475 r_ui = None   est = 4.05   {'was_impossible': False}
# user: 5          item: 830969158436936588 r_ui = None   est = 4.29   {'was_impossible': False}
# user: 5          item: 831008711204150847 r_ui = None   est = 4.53   {'was_impossible': False}
# user: 5          item: 831017287232611543 r_ui = None   est = 4.59   {'was_impossible': False}
# user: 5          item: 841311890462137145 r_ui = None   est = 3.64   {'was_impossible': False}
# user: 5          item: 841664984077062487 r_ui = None   est = 3.87   {'was_impossible': False}
# user: 5          item: 831024368851599396 r_ui = None   est = 4.16   {'was_impossible': False}
# user: 5          item: 841675872739484764 r_ui = None   est = 4.13   {'was_impossible': False}
# user: 5          item: 831028480502682984 r_ui = None   est = 4.28   {'was_impossible': False}
# user: 5          item: 831033318344000073 r_ui = None   est = 4.27   {'was_impossible': False}
# user: 5          item: 842009017449322673 r_ui = None   est = 4.53   {'was_impossible': False}
# user: 5          item: 846586276149703191 r_ui = None   est = 4.23   {'was_impossible': False}
# user: 5          item: 832538193209880053 r_ui = None   est = 4.62   {'was_impossible': False}
# user: 5          item: 846657479520768988 r_ui = None   est = 4.39   {'was_impossible': False}
# user: 5          item: 847387738667289885 r_ui = None   est = 3.72   {'was_impossible': False}
# user: 5          item: 832978163889399206 r_ui = None   est = 4.51   {'was_impossible': False}
# user: 5          item: 833053712139740266 r_ui = None   est = 4.12   {'was_impossible': False}
# user: 5          item: 847426428559637649 r_ui = None   est = 4.10   {'was_impossible': False}
# user: 5          item: 847528864890195254 r_ui = None   est = 3.55   {'was_impossible': False}
# user: 5          item: 833134612671614159 r_ui = None   est = 4.65   {'was_impossible': False}
# user: 5          item: 833134749137539055 r_ui = None   est = 4.47   {'was_impossible': False}
# user: 5          item: 833515666873745840 r_ui = None   est = 4.11   {'was_impossible': False}
# user: 5          item: 850284372406962940 r_ui = None   est = 4.29   {'was_impossible': False}
# user: 5          item: 837314171784091683 r_ui = None   est = 4.49   {'was_impossible': False}
# user: 5          item: 852149181396139440 r_ui = None   est = 4.44   {'was_impossible': False}
# user: 5          item: 852527793871911527 r_ui = None   est = 4.40   {'was_impossible': False}
# user: 5          item: 852711649412382555 r_ui = None   est = 4.52   {'was_impossible': False}
# user: 5          item: 852871951491349276 r_ui = None   est = 4.72   {'was_impossible': False}
# user: 5          item: 838867174319410951 r_ui = None   est = 4.53   {'was_impossible': False}
# user: 5          item: 852871981598768110 r_ui = None   est = 3.83   {'was_impossible': False}
# user: 5          item: 857219623289410236 r_ui = None   est = 4.46   {'was_impossible': False}
# user: 5          item: 857219667824194226 r_ui = None   est = 4.57   {'was_impossible': False}
# user: 5          item: 853123534601698361 r_ui = None   est = 4.40   {'was_impossible': False}
# user: 5          item: 853137147766803126 r_ui = None   est = 4.38   {'was_impossible': False}
# user: 5          item: 860866850109676130 r_ui = None   est = 4.26   {'was_impossible': False}
# user: 5          item: 853329655146229701 r_ui = None   est = 4.59   {'was_impossible': False}
# user: 5          item: 860867368583031545 r_ui = None   est = 4.00   {'was_impossible': False}
# user: 5          item: 853333353954940277 r_ui = None   est = 4.54   {'was_impossible': False}
# user: 5          item: 860890688959234207 r_ui = None   est = 4.58   {'was_impossible': False}
# user: 5          item: 860891616971085815 r_ui = None   est = 4.33   {'was_impossible': False}
# user: 5          item: 861306142531033900 r_ui = None   est = 4.49   {'was_impossible': False}
# user: 5          item: 854000299997801222 r_ui = None   est = 4.54   {'was_impossible': False}
# user: 5          item: 854147454206221585 r_ui = None   est = 4.39   {'was_impossible': False}
# user: 5          item: 863615482548080636 r_ui = None   est = 4.67   {'was_impossible': False}
# user: 5          item: 857219607985909970 r_ui = None   est = 3.60   {'was_impossible': False}
# user: 5          item: 873140807907520877 r_ui = None   est = 4.40   {'was_impossible': False}
# user: 5          item: 864096593582572949 r_ui = None   est = 4.46   {'was_impossible': False}
# user: 5          item: 864284821902520357 r_ui = None   est = 4.49   {'was_impossible': False}
# user: 5          item: 866254738186485422 r_ui = None   est = 4.34   {'was_impossible': False}
# user: 5          item: 873140844618962944 r_ui = None   est = 4.41   {'was_impossible': False}
# user: 5          item: 873151302770286080 r_ui = None   est = 4.50   {'was_impossible': False}
# user: 5          item: 873151314336193539 r_ui = None   est = 4.51   {'was_impossible': False}
# user: 5          item: 866644541769260130 r_ui = None   est = 4.41   {'was_impossible': False}
# user: 5          item: 873151554401594108 r_ui = None   est = 4.39   {'was_impossible': False}
# user: 5          item: 866672448659055675 r_ui = None   est = 4.17   {'was_impossible': False}
# user: 5          item: 866672591387841137 r_ui = None   est = 4.44   {'was_impossible': False}
# user: 5          item: 873151615789259032 r_ui = None   est = 4.61   {'was_impossible': False}
# user: 5          item: 873151881500059276 r_ui = None   est = 4.53   {'was_impossible': False}
# user: 5          item: 867062841312887598 r_ui = None   est = 4.86   {'was_impossible': False}
# user: 5          item: 873159641216775580 r_ui = None   est = 4.55   {'was_impossible': False}
# user: 5          item: 874107239608754176 r_ui = None   est = 4.38   {'was_impossible': False}
# user: 5          item: 867839684888565674 r_ui = None   est = 4.65   {'was_impossible': False}
# user: 5          item: 883715978457860924 r_ui = None   est = 4.37   {'was_impossible': False}
# user: 5          item: 868147808661410652 r_ui = None   est = 4.63   {'was_impossible': False}
# user: 5          item: 868252151595997909 r_ui = None   est = 4.72   {'was_impossible': False}
# user: 5          item: 868403865400796270 r_ui = None   est = 4.67   {'was_impossible': False}
# user: 5          item: 869099179388879329 r_ui = None   est = 4.55   {'was_impossible': False}
# user: 5          item: 887357986007611131 r_ui = None   est = 4.37   {'was_impossible': False}
# user: 5          item: 870150798623777606 r_ui = None   est = 4.53   {'was_impossible': False}
# user: 5          item: 870814564579138590 r_ui = None   est = 3.86   {'was_impossible': False}
# user: 5          item: 871753753112453460 r_ui = None   est = 4.05   {'was_impossible': False}
# user: 5          item: 890235246478507057 r_ui = None   est = 4.54   {'was_impossible': False}
# user: 5          item: 891323666287873479 r_ui = None   est = 4.49   {'was_impossible': False}
# user: 5          item: 872004459726043279 r_ui = None   est = 3.71   {'was_impossible': False}
# user: 5          item: 872029398374210817 r_ui = None   est = 4.40   {'was_impossible': False}
# user: 5          item: 872033189275592946 r_ui = None   est = 4.51   {'was_impossible': False}
# user: 5          item: 892382752394648175 r_ui = None   est = 4.46   {'was_impossible': False}
# user: 5          item: 872047481515351003 r_ui = None   est = 3.94   {'was_impossible': False}
# user: 5          item: 872055666279127955 r_ui = None   est = 4.43   {'was_impossible': False}
# user: 5          item: 872077453625517407 r_ui = None   est = 4.63   {'was_impossible': False}
# user: 5          item: 892552803811984250 r_ui = None   est = 4.41   {'was_impossible': False}
# user: 5          item: 893889200671916652 r_ui = None   est = 4.76   {'was_impossible': False}
# user: 5          item: 893967922982939874 r_ui = None   est = 4.58   {'was_impossible': False}
# user: 5          item: 872707446083348250 r_ui = None   est = 4.60   {'was_impossible': False}
# user: 5          item: 896425633723099478 r_ui = None   est = 4.14   {'was_impossible': False}
# user: 5          item: 896430082593981126 r_ui = None   est = 4.69   {'was_impossible': False}
# user: 5          item: 916046542020252484 r_ui = None   est = 4.48   {'was_impossible': False}
# user: 5          item: 916555505303421556 r_ui = None   est = 4.46   {'was_impossible': False}
# user: 5          item: 917058383793235848 r_ui = None   est = 4.71   {'was_impossible': False}
# user: 5          item: 896430178435129145 r_ui = None   est = 4.55   {'was_impossible': False}
# user: 5          item: 896430253027144500 r_ui = None   est = 4.38   {'was_impossible': False}
# user: 5          item: 896430291257384086 r_ui = None   est = 4.55   {'was_impossible': False}
# user: 5          item: 896430325231305607 r_ui = None   est = 4.57   {'was_impossible': False}
# user: 5          item: 917885193029724900 r_ui = None   est = 3.85   {'was_impossible': False}
# user: 5          item: 896430389474889508 r_ui = None   est = 4.44   {'was_impossible': False}
# user: 5          item: 896430801998622105 r_ui = None   est = 4.37   {'was_impossible': False}
# user: 5          item: 897448879002896896 r_ui = None   est = 4.59   {'was_impossible': False}
# user: 5          item: 897944820619377336 r_ui = None   est = 4.53   {'was_impossible': False}
# user: 5          item: 898183527940878966 r_ui = None   est = 4.52   {'was_impossible': False}
# user: 5          item: 919330824746585701 r_ui = None   est = 3.60   {'was_impossible': False}
# user: 5          item: 921632579190690942 r_ui = None   est = 3.78   {'was_impossible': False}
# user: 5          item: 901641165234551207 r_ui = None   est = 4.37   {'was_impossible': False}
# user: 5          item: 903245282160561730 r_ui = None   est = 4.70   {'was_impossible': False}
# user: 5          item: 903518796587993799 r_ui = None   est = 4.47   {'was_impossible': False}
# user: 5          item: 924948083412546988 r_ui = None   est = 4.62   {'was_impossible': False}
# user: 5          item: 903676444399048828 r_ui = None   est = 4.34   {'was_impossible': False}
# user: 5          item: 904928458664559242 r_ui = None   est = 4.52   {'was_impossible': False}
# user: 5          item: 904930311603763987 r_ui = None   est = 4.39   {'was_impossible': False}
# user: 5          item: 905791745825543748 r_ui = None   est = 4.64   {'was_impossible': False}
# user: 5          item: 909345580311355411 r_ui = None   est = 3.97   {'was_impossible': False}
# user: 5          item: 927092195097805859 r_ui = None   est = 4.34   {'was_impossible': False}
# user: 5          item: 910070794743590342 r_ui = None   est = 4.46   {'was_impossible': False}
# user: 5          item: 927970160066472278 r_ui = None   est = 4.68   {'was_impossible': False}
# user: 5          item: 911843758881109609 r_ui = None   est = 4.14   {'was_impossible': False}
# user: 5          item: 911877625557497697 r_ui = None   est = 3.67   {'was_impossible': False}
# user: 5          item: 930858735235682132 r_ui = None   est = 3.73   {'was_impossible': False}
# user: 5          item: 914147063287904750 r_ui = None   est = 4.51   {'was_impossible': False}
# user: 5          item: 932325448513127523 r_ui = None   est = 4.66   {'was_impossible': False}
# user: 5          item: 914844867933445346 r_ui = None   est = 4.09   {'was_impossible': False}
# user: 5          item: 932524310314197384 r_ui = None   est = 4.48   {'was_impossible': False}
# user: 5          item: 933101857279294843 r_ui = None   est = 4.61   {'was_impossible': False}
# user: 5          item: 935094489055741434 r_ui = None   est = 4.45   {'was_impossible': False}
# user: 5          item: 935358192780764304 r_ui = None   est = 4.74   {'was_impossible': False}
# user: 5          item: 938069818849113705 r_ui = None   est = 4.41   {'was_impossible': False}
# user: 5          item: 938304613932393020 r_ui = None   est = 4.39   {'was_impossible': False}
# user: 5          item: 938672532615874999 r_ui = None   est = 4.63   {'was_impossible': False}
# user: 5          item: 938966512075681026 r_ui = None   est = 4.50   {'was_impossible': False}
# user: 5          item: 941368278568586185 r_ui = None   est = 4.46   {'was_impossible': False}
# user: 5          item: 942238998443573026 r_ui = None   est = 4.65   {'was_impossible': False}
# user: 5          item: 943353249499062875 r_ui = None   est = 4.45   {'was_impossible': False}
# user: 5          item: 960008665521131399 r_ui = None   est = 4.64   {'was_impossible': False}
# user: 5          item: 945629358694056696 r_ui = None   est = 4.43   {'was_impossible': False}
# user: 5          item: 946218516981428518 r_ui = None   est = 4.65   {'was_impossible': False}
# user: 5          item: 960045451271498035 r_ui = None   est = 4.59   {'was_impossible': False}
# user: 5          item: 960047545627310289 r_ui = None   est = 4.32   {'was_impossible': False}
# user: 5          item: 963205217138532470 r_ui = None   est = 4.46   {'was_impossible': False}
# user: 5          item: 946262937217371544 r_ui = None   est = 4.16   {'was_impossible': False}
# user: 5          item: 968125040020566646 r_ui = None   est = 4.54   {'was_impossible': False}
# user: 5          item: 948700412652397998 r_ui = None   est = 4.48   {'was_impossible': False}
# user: 5          item: 969863516487779068 r_ui = None   est = 4.36   {'was_impossible': False}
# user: 5          item: 949216821315560523 r_ui = None   est = 4.50   {'was_impossible': False}
# user: 5          item: 950475779057314849 r_ui = None   est = 4.52   {'was_impossible': False}
# [(1941719, 5),
#  (6287204, 5),
#  (16044788, 5),
#  (24979153, 5),
#  (28264364, 4.996494226982046),
#  (4541183, 4.98494562290707),
#  (31003554, 4.982231646421834),
#  (12702541, 4.980697755075249),
#  (675870259202962455, 4.97545886946243),
#  (17601150, 4.957347009186385)]

# %%
recommendations_df = pd.DataFrame(recommendations, columns=['id', 'est_rating'])


recommended_items_info = item_info[item_info['id'].isin(recommendations_df['id'])]

recommended_items_info = recommended_items_info.merge(recommendations_df, on='id').sort_values(by='est_rating', ascending=False)
recommended_items_info=recommended_items_info.drop('est_rating', axis=1)
recommended_items_info
# Out:
#              id                           name  \
# 0  1.941719e+06         Condo in Downtown Core
# 2  6.287204e+06             Condo in Woodlands
# 4  1.604479e+07          Rental unit in Newton
# 5  2.497915e+07     Rental unit in Bukit Merah
# 6  2.826436e+07          Rental unit in Rochor
# 1  4.541183e+06  Aparthotel in Singapore River
# 7  3.100355e+07  Serviced apartment in Kallang
# 3  1.270254e+07                Condo in Rochor
# 8  6.758703e+17   Serviced apartment in Outram
#
#                                 details neighbourhood_cleansed  \
# 0     1 bedroom · 1 bed · 1 shared bath          Downtown Core
# 2           1 bedroom · 2 beds · 1 bath              Woodlands
# 4    1 bedroom · 1 bed · 1 private bath                 Newton
# 5  1 bedroom · 1 bed · 1.5 shared baths            Bukit Merah
# 6            1 bedroom · 1 bed · 1 bath                 Rochor
# 1               Studio · 1 bed · 1 bath        Singapore River
# 7            1 bedroom · 1 bed · 1 bath                Kallang
# 3               Studio · 1 bed · 1 bath                 Rochor
# 8          2 bedrooms · 2 beds · 1 bath                 Outram
#
#   neighbourhood_group_cleansed  \
# 0               Central Region
# 2                 North Region
# 4               Central Region
# 5               Central Region
# 6               Central Region
# 1               Central Region
# 7               Central Region
# 3               Central Region
# 8               Central Region
#
#                                          picture_url  latitude  longitude  \
# 0  https://a0.muscache.com/pictures/ba895238-3fb4...   1.27525  103.84524
# 2  https://a0.muscache.com/pictures/81317317/1934...   1.43012  103.78434
# 4  https://a0.muscache.com/pictures/5e2ce849-45d1...   1.30641  103.84045
# 5  https://a0.muscache.com/pictures/802c2389-ecd4...   1.28286  103.83403
# 6  https://a0.muscache.com/pictures/c7489e19-2cd6...   1.30331  103.84870
# 1  https://a0.muscache.com/pictures/5dd4acc0-79c5...   1.28816  103.84826
# 7  https://a0.muscache.com/pictures/miso/Hosting-...   1.29966  103.88497
# 3  https://a0.muscache.com/pictures/8a9a8d7a-4926...   1.30409  103.84650
# 8  https://a0.muscache.com/pictures/dede8e29-6341...   1.28168  103.84673
#
#          room_type    price  ...  stove  fan  review_scores_rating  \
# 0     Private room   3570.0  ...    1.0  0.0                  4.51
# 2  Entire home/apt   5400.0  ...    1.0  1.0                  4.80
# 4     Private room   3180.0  ...    1.0  0.0                  4.36
# 5     Private room   1800.0  ...    0.0  0.0                  4.62
# 6  Entire home/apt   4350.0  ...    1.0  0.0                  4.69
# 1  Entire home/apt   5430.0  ...    0.0  0.0                  4.79
# 7  Entire home/apt   5460.0  ...    1.0  0.0                  4.83
# 3  Entire home/apt   7200.0  ...    0.0  0.0                  4.69
# 8  Entire home/apt  12360.0  ...    0.0  0.0                  4.75
#
#   review_scores_accuracy review_scores_cleanliness  review_scores_checkin  \
# 0                   4.62                      4.63                   4.67
# 2                   4.80                      4.60                   5.00
# 4                   4.31                      3.85                   4.62
# 5                   4.80                      4.80                   4.90
# 6                   4.73                      4.65                   5.00
# 1                   4.81                      4.84                   4.79
# 7                   4.92                      4.91                   4.95
# 3                   4.88                      4.81                   4.83
# 8                   4.75                      4.50                   4.75
#
#   review_scores_communication  review_scores_location review_scores_value  \
# 0                        4.67                    4.85                4.46
# 2                        4.90                    4.50                4.30
# 4                        4.62                    4.85                4.23
# 5                        4.91                    4.72                4.73
# 6                        4.96                    4.88                4.58
# 1                        4.89                    4.89                4.69
# 7                        4.83                    4.59                4.75
# 3                        4.96                    4.75                4.83
# 8                        5.00                    5.00                4.75
#
#                                        listing_url
# 0             https://www.airbnb.com/rooms/1941719
# 2             https://www.airbnb.com/rooms/6287204
# 4            https://www.airbnb.com/rooms/16044788
# 5            https://www.airbnb.com/rooms/24979153
# 6            https://www.airbnb.com/rooms/28264364
# 1             https://www.airbnb.com/rooms/4541183
# 7            https://www.airbnb.com/rooms/31003554
# 3            https://www.airbnb.com/rooms/12702541
# 8  https://www.airbnb.com/rooms/675839404447270831
#
# [9 rows x 42 columns]
